# %%
import pandas as pd

# %%
thorium_deposits = [
    (8.18,  77.42, "Manavalakurichi, TN",  300),
    (19.85, 85.97, "Chhatrapur, Odisha",   260),
    (9.95,  76.27, "Chavara, Kerala",       120),
    (20.27, 86.90, "Gopalpur, Odisha",       80),
    (13.59, 80.18, "Nellore, AP",            60),
    (22.31, 87.32, "Junput, WB",             55),
    (15.34, 73.93, "Goa Coast",              40),
]

# %%
df_thorium = pd.DataFrame(thorium_deposits, columns=['latitude', 'longitude', 'location', 'reserve_kt'])
df_thorium.to_csv('thorium_deposits.csv', index=False)
print(df_thorium)
# Out:
#    latitude  longitude             location  reserve_kt
# 0      8.18      77.42  Manavalakurichi, TN         300
# 1     19.85      85.97   Chhatrapur, Odisha         260
# 2      9.95      76.27      Chavara, Kerala         120
# 3     20.27      86.90     Gopalpur, Odisha          80
# 4     13.59      80.18          Nellore, AP          60
# 5     22.31      87.32           Junput, WB          55
# 6     15.34      73.93            Goa Coast          40

# %%
reactor_sites = [
    (15.34, 73.93, "Karwar, Goa/Karnataka",    85.2),
    (13.62, 80.22, "Pulicat, AP",              82.8),
    (8.20,  77.45, "Manavalakurichi, TN",      82.5),
    (9.58,  76.35, "Kayamkulam, Kerala",       80.6),
    (19.30, 85.02, "Dhamra, Odisha",           77.6),
    (11.92, 79.83, "Pondicherry Coast",        75.0),
    (14.90, 80.27, "Nellore Coast, AP",        74.5),
]

# %%
df_sites = pd.DataFrame(reactor_sites, columns=['latitude', 'longitude', 'site_name', 'score'])
df_sites.to_csv('reactor_sites_qgis.csv', index=False)
print(df_sites)
# Out:
#    latitude  longitude              site_name  score
# 0     15.34      73.93  Karwar, Goa/Karnataka   85.2
# 1     13.62      80.22            Pulicat, AP   82.8
# 2      8.20      77.45    Manavalakurichi, TN   82.5
# 3      9.58      76.35     Kayamkulam, Kerala   80.6
# 4     19.30      85.02         Dhamra, Odisha   77.6
# 5     11.92      79.83      Pondicherry Coast   75.0
# 6     14.90      80.27      Nellore Coast, AP   74.5
